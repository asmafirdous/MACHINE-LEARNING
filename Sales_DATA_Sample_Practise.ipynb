# %%
import numpy  as np
import pandas as pd
import matplotlib as plot
import sklearn as sk

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-919743f6-c474-4b34-8618-3d5dd48aa3b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-919743f6-c474-4b34-8618-3d5dd48aa3b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('sales_data_sample (2).csv', encoding='unicode_escape')

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df=df.drop(['ADDRESSLINE2'],axis=1)
df=df.drop(['ADDRESSLINE1'],axis=1)
df=df.drop(['QTR_ID'],axis=1)
df=df.drop(['MONTH_ID'],axis=1)
df=df.drop(['YEAR_ID'],axis=1)
df=df.drop(['PRODUCTLINE'],axis=1)
df=df.drop(['CONTACTLASTNAME'],axis=1)
df=df.drop(['CONTACTFIRSTNAME'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-1a08a3e5e8af> in <module>
# ----> 1 df=df.drop(['ADDRESSLINE2'],axis=1)
#       2 df=df.drop(['ADDRESSLINE1'],axis=1)
#       3 df=df.drop(['QTR_ID'],axis=1)
#       4 df=df.drop(['MONTH_ID'],axis=1)
#       5 df=df.drop(['YEAR_ID'],axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  MSRP PRODUCTCODE              CUSTOMERNAME  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# PHONE                 0
# CITY                  0
# STATE              1486
# POSTALCODE           76
# COUNTRY               0
# TERRITORY          1074
# DEALSIZE              0
# dtype: int64

# %%
df['STATE'].value_counts().plot(kind='bar')

# %%
df['TERRITORY'].value_counts().plot(kind='bar')

# %%
df['STATUS'].value_counts().plot(kind='bar')

# %%
df.groupby('TERRITORY').SALES.sum()
# Out:
# TERRITORY
# APAC      746121.83
# EMEA     4979272.41
# Japan     455173.22
# Name: SALES, dtype: float64

# %%
df.groupby('TERRITORY').STATUS.count()
# Out:
# TERRITORY
# APAC      221
# EMEA     1407
# Japan     121
# Name: STATUS, dtype: int64

# %%
df['TERRITORY'] = df['TERRITORY'].fillna(df['TERRITORY'].mode()[0])

# %%
df['STATE'] = df['STATE'].fillna(df['STATE'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# CITY                0
# STATE               0
# POSTALCODE         76
# COUNTRY             0
# TERRITORY           0
# DEALSIZE            0
# dtype: int64

# %%
df=df.drop(['POSTALCODE'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-7a3315d479dc> in <module>
# ----> 1 df=df.drop(['POSTALCODE'], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df=df.drop(['PRODUCTCODE'], axis=1)
df=df.drop(['CUSTOMERNAME'], axis=1)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  MSRP             PHONE           CITY STATE  \
# ...

# %% [markdown]
# Observation :
# THe given sales sample data is analysed and captured the below points.
# 1.   Categorical fields as such ADDRESSLINE2,ADDRESSLINE1',QTR_ID,MONTH_ID,YEAR_ID,PRODUCTLINE,CONTACTLASTNAME,CONTACTFIRSTNAME adds no value, thus features are dropped
# 2.   Nullvalues captured across the features TERRITORY and STATE. As its categorical replaced with mode.
# 3.   The maximum sales happened for the territory EMEA
# 4.  The maximum item shipped happened for the territory EMEA
